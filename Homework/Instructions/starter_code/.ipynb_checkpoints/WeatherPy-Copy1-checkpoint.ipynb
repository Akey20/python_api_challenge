# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime
import scipy.stats as st

# Import API key
from api_keys import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []



# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
url = "api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#url 
query_url = f"{url}appid={weather_api_key}&units={units}&q="
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#creating sample list of cities to use instead of calling all for testing. remove before final push & to test full file
small_cities = cities[:85]
print(small_cities)
# Out:
# ['busselton', 'xining', 'butzow', 'fort nelson', 'hobyo', 'tuktoyaktuk', 'saint george', 'avarua', 'taolanaro', 'yellowknife', 'margate', 'punta arenas', 'bluff', 'mataura', 'haibowan', 'kapaa', 'halalo', 'albany', 'udachnyy', 'ribeira grande', 'cape town', 'sitka', 'nipawin', 'rikitea', 'mapiripan', 'ushuaia', 'ust-kamchatsk', 'newcastleton', 'ambovombe', 'cidreira', 'hilo', 'nikolskoye', 'hobart', 'hurricane', 'grand gaube', 'jamestown', 'gorno-chuyskiy', 'anuchino', 'jumla', 'mar del plata', 'haines junction', 'strelka', 'ayan', 'caravelas', 'oktyabrskoye', 'victoria', 'guerrero', 'hithadhoo', 'flinders', 'tiksi', 'severo-kurilsk', 'vuktyl', 'tselina', 'atuona', 'kalomo', 'toliary', 'namatanai', 'sorvag', 'faanui', 'barentsburg', 'cockburn town', 'zhigansk', 'nanortalik', 'havoysund', 'tasiilaq', 'yantal', 'riyadh', 'moussoro', 'san patricio', 'muros', 'saldanha', 'vostok', 'namibe', 'port alfred', 'young', 'asau', 'tornio', 'norman wells', 'la ronge', 'saint-pierre', 'chebenki', 'tarata', 'vila velha', 'georgetown', 'zyryanskoye']

# %%
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#lists to be populated w/ weather data
city_name = []
country = []
latitude =[]
longitude = []
date = []
temperature = []
wind_speed = []
cloud_cover = []
humidity = []



counter = 1

#for city in small_cities:   # used this smaller list for testing remove and use for city in cities for prod
for city in cities:
    
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        date.append(response["dt"])
        temperature.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        cloud_cover.append(response["clouds"]["all"])
        humidity.append(response["main"]["humidity"])
        
        print(f"city  {counter} | {city}")
        #print(f"{url}&q={city}")
        
        counter = counter + 1
        time.sleep(1.05)
    except:
        
        
        print("No city found. Skipping...")
        
    continue
print("All Done!")
# Out:
# city  1 | busselton
# city  2 | xining
# city  3 | butzow
# city  4 | fort nelson
# city  5 | hobyo
# city  6 | tuktoyaktuk
# city  7 | saint george
# city  8 | avarua
# No city found. Skipping...
# city  9 | yellowknife
# city  10 | margate
# city  11 | punta arenas
# city  12 | bluff
# city  13 | mataura
# No city found. Skipping...
# city  14 | kapaa
# No city found. Skipping...
# city  15 | albany
# city  16 | udachnyy
# city  17 | ribeira grande
# city  18 | cape town
# city  19 | sitka
# city  20 | nipawin
# city  21 | rikitea
# city  22 | mapiripan
# city  23 | ushuaia
# No city found. Skipping...
# city  24 | newcastleton
# city  25 | ambovombe
# city  26 | cidreira
# city  27 | hilo
# city  28 | nikolskoye
# city  29 | hobart
# city  30 | hurricane
# city  31 | grand gaube
# city  32 | jamestown
# No city found. Skipping...
# city  33 | anuchino
# city  34 | jumla
# city  35 | mar del plata
# city  36 | haines junction
# city  37 | strelka
# city  38 | ayan
# city  39 | caravelas
# city  40 | oktyabrskoye
# city  41 | victoria
# city  42 | guerrero
# city  43 | hithadhoo
# city  44 | flinders
# city  45 | tiksi
# city  46 | severo-kurilsk
# city  47 | vuktyl
# city  48 | tselina
# city  49 | atuona
# No city found. Skipping...
# No city found. Skipping...
# city  50 | namatanai
# No city found. Skipping...
# city  51 | faanui
# No city found. Skipping...
# city  52 | cockburn town
# city  53 | zhigansk
# city  54 | nanortalik
# city  55 | havoysund
# city  56 | tasiilaq
# city  57 | yantal
# city  58 | riyadh
# city  59 | moussoro
# city  60 | san patricio
# city  61 | muros
# city  62 | saldanha
# city  63 | vostok
# city  64 | namibe
# city  65 | port alfred
# city  66 | young
# city  67 | asau
# city  68 | tornio
# city  69 | norman wells
# city  70 | la ronge
# city  71 | saint-pierre
# city  72 | chebenki
# city  73 | tarata
# city  74 | vila velha
# city  75 | georgetown
# city  76 | zyryanskoye
# city  77 | mahebourg
# city  78 | loukhi
# city  79 | bilibino
# No city found. Skipping...
# city  80 | rundu
# city  81 | grindavik
# city  82 | bilma
# city  83 | pevek
# No city found. Skipping...
# city  84 | santa teresa
# city  85 | new norfolk
# city  86 | haverfordwest
# No city found. Skipping...
# No city found. Skipping...
# city  87 | manggar
# city  88 | puerto ayora
# city  89 | bolgatanga
# No city found. Skipping...
# city  90 | east bethel
# city  91 | salalah
# city  92 | east london
# city  93 | cap-aux-meules
# city  94 | geraldton
# city  95 | broome
# city  96 | alexandria
# city  97 | jiangkou
# city  98 | kiruna
# city  99 | petropavlovsk-kamchatskiy
# city  100 | okha
# city  101 | port lincoln
# city  102 | faenza
# city  103 | khatanga
# No city found. Skipping...
# city  104 | guerrero negro
# city  105 | arraial do cabo
# city  106 | ishigaki
# city  107 | shingu
# city  108 | hervey bay
# city  109 | ponta do sol
# city  110 | hermanus
# city  111 | half moon bay
# city  112 | simao
# city  113 | kahului
# city  114 | ossora
# city  115 | leh
# city  116 | castro
# city  117 | matay
# city  118 | antofagasta
# city  119 | comodoro rivadavia
# city  120 | grootfontein
# city  121 | la carolina
# city  122 | staraya poltavka
# city  123 | veraval
# city  124 | hay river
# city  125 | henties bay
# city  126 | puerto colombia
# city  127 | ube
# city  128 | cabo san lucas
# city  129 | balkanabat
# No city found. Skipping...
# city  130 | dikson
# No city found. Skipping...
# city  131 | souillac
# city  132 | dombarovskiy
# city  133 | arman
# city  134 | hambantota
# city  135 | omboue
# city  136 | ulaangom
# city  137 | shimoda
# city  138 | bredasdorp
# city  139 | pangnirtung
# city  140 | adamovka
# city  141 | olafsvik
# city  142 | thompson
# city  143 | chuchkovo
# city  144 | fortuna
# city  145 | kieta
# city  146 | aksarka
# city  147 | jardim
# city  148 | kirkenaer
# city  149 | kupang
# city  150 | butaritari
# city  151 | saskylakh
# city  152 | traverse city
# No city found. Skipping...
# city  153 | leningradskiy
# city  154 | barrow
# city  155 | vardo
# city  156 | ambulu
# city  157 | bengkulu
# city  158 | kodiak
# city  159 | longyearbyen
# city  160 | watertown
# city  161 | dingle
# city  162 | madimba
# city  163 | saint-joseph
# city  164 | belogorsk
# city  165 | lompoc
# No city found. Skipping...
# city  166 | bereznik
# city  167 | kirakira
# city  168 | clyde river
# city  169 | tuatapere
# city  170 | yelizovo
# city  171 | tacoronte
# city  172 | grand-lahou
# city  173 | te anau
# No city found. Skipping...
# city  174 | sakakah
# city  175 | qaanaaq
# city  176 | atbasar
# city  177 | mehamn
# city  178 | chuy
# city  179 | rigaud
# city  180 | anadyr
# city  181 | fujin
# city  182 | abu kamal
# city  183 | kalmunai
# No city found. Skipping...
# city  184 | carnarvon
# city  185 | tezu
# city  186 | alice springs
# city  187 | san vicente
# city  188 | tvoroyri
# city  189 | biloela
# city  190 | yining
# city  191 | upernavik
# city  192 | tartagal
# No city found. Skipping...
# city  193 | jacareacanga
# city  194 | kot samaba
# city  195 | biograd na moru
# city  196 | mlowo
# city  197 | hailar
# city  198 | bandar
# city  199 | vestmannaeyjar
# No city found. Skipping...
# city  200 | jacmel
# city  201 | sambava
# city  202 | bethel
# city  203 | aloleng
# city  204 | stornoway
# city  205 | coquimbo
# city  206 | dunmore east
# No city found. Skipping...
# city  207 | sancti spiritus
# city  208 | palmas bellas
# city  209 | bonavista
# city  210 | conselheiro pena
# city  211 | mayskiy
# city  212 | balod
# city  213 | bambous virieux
# city  214 | san andres
# city  215 | touros
# city  216 | senden
# city  217 | mount gambier
# city  218 | amboise
# city  219 | mayo
# city  220 | umm kaddadah
# city  221 | shepetivka
# city  222 | jutai
# city  223 | warora
# city  224 | kaitangata
# city  225 | north bend
# city  226 | qaqortoq
# city  227 | camacha
# city  228 | rincon
# city  229 | christiana
# city  230 | buenos aires
# city  231 | fukue
# city  232 | santa isabel do rio negro
# city  233 | berlevag
# city  234 | awjilah
# No city found. Skipping...
# city  235 | torrington
# city  236 | loknya
# city  237 | razdolnoye
# city  238 | tomislavgrad
# city  239 | saint anthony
# city  240 | terrace
# city  241 | poltavka
# city  242 | lavrentiya
# city  243 | eydhafushi
# city  244 | hohhot
# city  245 | gandajika
# city  246 | cascais
# city  247 | provideniya
# city  248 | naze
# city  249 | trelew
# city  250 | plettenberg bay
# city  251 | hangzhou
# city  252 | ancud
# city  253 | constitucion
# city  254 | vila do maio
# No city found. Skipping...
# city  255 | ambilobe
# No city found. Skipping...
# city  256 | padang
# city  257 | makakilo city
# city  258 | cherskiy
# city  259 | port elizabeth
# city  260 | fuyang
# city  261 | klaksvik
# city  262 | bukachacha
# city  263 | hami
# No city found. Skipping...
# city  264 | ixtapa
# city  265 | palana
# city  266 | sorland
# city  267 | roald
# city  268 | mangrol
# city  269 | twin falls
# city  270 | lazaro cardenas
# city  271 | san cristobal
# city  272 | zorgo
# city  273 | saint-philippe
# city  274 | chokurdakh
# city  275 | tessalit
# city  276 | ilulissat
# No city found. Skipping...
# city  277 | elk plain
# city  278 | monteiro
# city  279 | poum
# No city found. Skipping...
# city  280 | pisco
# city  281 | kodinsk
# city  282 | pak phanang
# city  283 | kaeo
# city  284 | torbay
# city  285 | lorengau
# city  286 | ulladulla
# city  287 | sweetwater
# city  288 | coxim
# city  289 | pervomayskoye
# city  290 | antalaha
# city  291 | nome
# city  292 | san jeronimo
# city  293 | popondetta
# city  294 | talnakh
# city  295 | coahuayana
# city  296 | san quintin
# No city found. Skipping...
# city  297 | kadyy
# city  298 | frontera
# city  299 | venado tuerto
# city  300 | srikakulam
# city  301 | kavaratti
# No city found. Skipping...
# No city found. Skipping...
# city  302 | lebu
# city  303 | hakodate
# city  304 | beaverlodge
# city  305 | miyako
# city  306 | arlit
# city  307 | beringovskiy
# city  308 | vaini
# city  309 | sola
# city  310 | nicoya
# city  311 | batticaloa
# city  312 | hidas
# city  313 | iqaluit
# city  314 | nishihara
# city  315 | bubaque
# city  316 | martinho campos
# city  317 | avera
# city  318 | komsomolskiy
# city  319 | gat
# city  320 | hasaki
# city  321 | kavieng
# city  322 | buraydah
# city  323 | san jose
# city  324 | nuuk
# city  325 | abalak
# city  326 | harsin
# No city found. Skipping...
# No city found. Skipping...
# city  327 | nouadhibou
# city  328 | bronzani majdan
# city  329 | narsaq
# city  330 | airai
# city  331 | sarahan
# city  332 | matara
# city  333 | richards bay
# city  334 | great falls
# city  335 | harper
# city  336 | poykovskiy
# city  337 | hanzhong
# No city found. Skipping...
# city  338 | saltillo
# city  339 | sao joao da barra
# city  340 | catuday
# city  341 | san rafael
# city  342 | gravdal
# city  343 | sao filipe
# city  344 | bangassou
# city  345 | cochrane
# city  346 | tahoua
# city  347 | buala
# city  348 | kudahuvadhoo
# city  349 | deputatskiy
# city  350 | kathu
# city  351 | broken hill
# city  352 | mayumba
# city  353 | ostrovnoy
# city  354 | santo antonio do leverger
# city  355 | katsuura
# city  356 | bourail
# city  357 | salinopolis
# city  358 | akhtanizovskaya
# city  359 | cavalcante
# No city found. Skipping...
# city  360 | abha
# city  361 | thinadhoo
# city  362 | kikwit
# city  363 | ekibastuz
# city  364 | auki
# city  365 | thunder bay
# city  366 | mandalgovi
# city  367 | hamilton
# city  368 | sibay
# city  369 | gornoye loo
# No city found. Skipping...
# No city found. Skipping...
# city  370 | panjab
# city  371 | belyy yar
# city  372 | marystown
# city  373 | tsalka
# city  374 | santa rosa
# No city found. Skipping...
# city  375 | kos
# city  376 | moose factory
# city  377 | chardara
# No city found. Skipping...
# city  378 | gonbad-e qabus
# city  379 | zhoucheng
# city  380 | maniakoi
# city  381 | sungaipenuh
# city  382 | ginda
# city  383 | ugoofaaru
# city  384 | paamiut
# city  385 | rio grande
# city  386 | rondonopolis
# city  387 | fuzesabony
# No city found. Skipping...
# No city found. Skipping...
# city  388 | acajutla
# city  389 | amapa
# city  390 | cardenas
# city  391 | brae
# city  392 | englewood
# city  393 | kamenka
# city  394 | krasnoselkup
# city  395 | ihosy
# city  396 | jacqueville
# city  397 | bismarck
# city  398 | bathsheba
# city  399 | chapais
# city  400 | takapau
# city  401 | semey
# city  402 | kruisfontein
# city  403 | waipawa
# city  404 | hofn
# city  405 | luancheng
# city  406 | newcastle
# city  407 | baie-comeau
# city  408 | kurayoshi
# No city found. Skipping...
# city  409 | nemuro
# city  410 | fairbanks
# city  411 | itarema
# city  412 | porto walter
# No city found. Skipping...
# city  413 | koslan
# city  414 | casa quemada
# city  415 | mansoa
# city  416 | kununurra
# city  417 | luderitz
# city  418 | caorle
# city  419 | portland
# city  420 | lagoa
# city  421 | collie
# city  422 | kota kinabalu
# city  423 | codrington
# city  424 | vanimo
# city  425 | yulara
# city  426 | pandan
# No city found. Skipping...
# city  427 | shitanjing
# city  428 | egvekinot
# city  429 | meulaboh
# city  430 | caconda
# city  431 | doha
# city  432 | umm lajj
# No city found. Skipping...
# city  433 | russell
# city  434 | ust-nera
# city  435 | borogontsy
# city  436 | jalu
# city  437 | columbus
# city  438 | dalvik
# city  439 | panguna
# city  440 | linqiong
# city  441 | northam
# city  442 | harnosand
# city  443 | billings
# city  444 | carroll
# city  445 | sept-iles
# city  446 | rawson
# city  447 | mantua
# No city found. Skipping...
# city  448 | bandrele
# city  449 | wattegama
# city  450 | maningrida
# city  451 | ahipara
# city  452 | seoul
# city  453 | daru
# city  454 | blyth
# city  455 | ayagoz
# city  456 | flin flon
# city  457 | vidim
# city  458 | kota belud
# city  459 | kisangani
# city  460 | dhidhdhoo
# city  461 | sorong
# city  462 | nisia floresta
# city  463 | inta
# city  464 | batagay-alyta
# city  465 | idlib
# No city found. Skipping...
# city  466 | mitsamiouli
# city  467 | ypsonas
# city  468 | piura
# city  469 | am timan
# city  470 | cururupu
# city  471 | odweyne
# city  472 | tatvan
# city  473 | mundo nuevo
# city  474 | chodziez
# city  475 | gayny
# city  476 | marsh harbour
# city  477 | nabire
# city  478 | manokwari
# city  479 | port macquarie
# city  480 | indramayu
# city  481 | wronki
# city  482 | sompeta
# city  483 | hammerfest
# city  484 | faya
# city  485 | kyabe
# city  486 | marrakesh
# city  487 | kawalu
# city  488 | husavik
# city  489 | tarauaca
# city  490 | imbituba
# city  491 | lugoba
# city  492 | aklavik
# city  493 | chakia
# city  494 | dunedin
# city  495 | oranjemund
# city  496 | sistranda
# city  497 | hovd
# city  498 | vieques
# city  499 | los llanos de aridane
# city  500 | zabaykalsk
# city  501 | guadalajara
# city  502 | lixourion
# city  503 | manaure
# city  504 | stepnyak
# city  505 | puerto del rosario
# city  506 | rudnogorsk
# city  507 | athabasca
# city  508 | chara
# city  509 | guarapari
# city  510 | sefophe
# No city found. Skipping...
# city  511 | tiszacsege
# city  512 | araraquara
# city  513 | lovozero
# city  514 | dunmore town
# city  515 | madinat sittah uktubar
# city  516 | tieli
# city  517 | bosaso
# city  518 | kurilsk
# city  519 | rizhao
# city  520 | wasco
# city  521 | port augusta
# city  522 | starkville
# city  523 | nueve de julio
# city  524 | slave lake
# city  525 | atar
# city  526 | wexford
# city  527 | iskateley
# city  528 | grafton
# city  529 | narovchat
# city  530 | wajima
# city  531 | maragogi
# city  532 | qui nhon
# city  533 | lamu
# city  534 | sete
# city  535 | saint-francois
# city  536 | simplicio mendes
# city  537 | suluq
# city  538 | victor harbor
# city  539 | vao
# city  540 | itoman
# city  541 | adrar
# city  542 | west wendover
# city  543 | songjianghe
# city  544 | viransehir
# city  545 | hastings
# city  546 | ust-tsilma
# No city found. Skipping...
# city  547 | kudat
# city  548 | khipro
# city  549 | burriana
# city  550 | kulhudhuffushi
# city  551 | ulaanbaatar
# city  552 | katherine
# city  553 | sarh
# All Done!

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#setup dataframe
city_df = pd.DataFrame({ "City": city_name, "Cloudiness": cloud_cover, "Country": country,
                        "Humidity": humidity, "Lat": latitude, "Long": longitude,
                       "Max Temp": temperature, "Wind": wind_speed, "Date": date})


city_df.to_csv('../output_data/city_df.csv')

# %%
city_df
# Out:
#                City  Cloudiness Country  Humidity      Lat      Long  \
# 0         Busselton          27      AU        57 -33.6500  115.3333
# 1            Xining          87      CN        87  36.6167  101.7667
# 2            Bützow         100      DE        84  53.8500   11.9833
# 3       Fort Nelson         100      CA        93  58.8053 -122.7002
# 4             Hobyo          66      SO        68   5.3505   48.5268
# ..              ...         ...     ...       ...      ...       ...
# 548        Burriana           1      ES        54  39.8890   -0.0850
# 549  Kulhudhuffushi          18      MV        70   6.6221   73.0700
# 550     Ulaanbaatar          75      MN        69  47.9077  106.8832
# 551       Katherine         100      AU        83 -14.4667  132.2667
# 552            Sarh           0      TD        29   9.1429   18.3923
#
#      Max Temp   Wind        Date
# 0       67.05   8.39  1643409792
# 1        8.08   3.11  1643409793
# 2       41.09  12.21  1643409794
# 3       18.99   9.22  1643409796
# 4       76.57  21.23  1643409711
# ..        ...    ...         ...
# 548     49.66   4.97  1643410560
# 549     81.23  19.48  1643410561
# 550    -21.87   0.00  1643410562
# 551     80.92  11.50  1643410564
# 552     78.71   0.00  1643410565
#
# [553 rows x 9 columns]

# %%
len(latitude)
# Out:
# 553

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_df.loc[city_df["Humidity"]> 100] ["Humidity"].count()
# when ran there were no cities with > 100 humidity
# Out:
# 0

# %%
#  Get the indices of cities that have humidity over 100%.
humid_100 = city_df[city_df.Humidity > 100].index
humid_100
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

clean_city_df = city_df.loc[city_df["Humidity"] < 100]
clean_city_df
# Out:
#                City  Cloudiness Country  Humidity      Lat      Long  \
# 0         Busselton          27      AU        57 -33.6500  115.3333
# 1            Xining          87      CN        87  36.6167  101.7667
# 2            Bützow         100      DE        84  53.8500   11.9833
# 3       Fort Nelson         100      CA        93  58.8053 -122.7002
# 4             Hobyo          66      SO        68   5.3505   48.5268
# ..              ...         ...     ...       ...      ...       ...
# 548        Burriana           1      ES        54  39.8890   -0.0850
# 549  Kulhudhuffushi          18      MV        70   6.6221   73.0700
# 550     Ulaanbaatar          75      MN        69  47.9077  106.8832
# 551       Katherine         100      AU        83 -14.4667  132.2667
# 552            Sarh           0      TD        29   9.1429   18.3923
#
#      Max Temp   Wind        Date
# 0       67.05   8.39  1643409792
# 1        8.08   3.11  1643409793
# 2       41.09  12.21  1643409794
# 3       18.99   9.22  1643409796
# 4       76.57  21.23  1643409711
# ..        ...    ...         ...
# 548     49.66   4.97  1643410560
# 549     81.23  19.48  1643410561
# 550    -21.87   0.00  1643410562
# 551     80.92  11.50  1643410564
# 552     78.71   0.00  1643410565
#
# [534 rows x 9 columns]

# %%
#count for clean city df
len(clean_city_df)
# Out:
# 534

# %%
len(city_df)
# Out:
# 553

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# The below scatter plot shows the relationship between Latitude and Max TempF. Notice how when you move farther from the equator the temps decrease.

# %%
date_time = datetime.date(datetime.now())
#create scatter plot
x_values = city_df["Lat"]
y_values = city_df["Max Temp"]
fig1, ax1 = plt.subplots(figsize=(8,5))
plt.scatter(x_values, y_values, alpha = 0.90, edgecolors = 'c', linewidths = 1)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.title(f"City Latitude v/ Max Temperature {date_time}")
plt.grid()
plt.savefig("../output_data/latitude_v_temp.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# The below scatter plot shows the relationship between Humidity % v/ Latitude.

# %%
x_values = city_df["Lat"]
y_values = city_df["Humidity"]
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values, alpha = 0.90, edgecolors = 'k', linewidths = 1)
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title(f"City Latitude v/ Humidity {date_time}")
plt.grid()
plt.savefig("../output_data/latitude_v_humidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# The below scatter plot shows the relationship between latitude and the city cloudiness. There appears to be no difference in cloudiness based on latitude of city.

# %%
x_values = city_df["Lat"]
y_values = city_df["Cloudiness"]
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values, alpha = 0.90, edgecolors = 'b', linewidths = 1)
plt.xlabel("Latitude")
plt.ylabel("Cloudniess")
plt.title(f"City Latitude v/ Cloudiness {date_time}")
plt.grid()
plt.savefig("../output_data/latitude_v_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# The below scatter plot shows the relationship between latitude and wind speed. It appears that wind speed increases for cities farther from the equator.

# %%
x_values = city_df["Lat"]
y_values = city_df["Wind"]
fig1, ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values, alpha = 0.90, edgecolors = 'k', linewidths = 1)
plt.xlabel("Latitude")
plt.ylabel("Wind")
plt.title(f"City Latitude v/ Wind Speed {date_time}")
plt.grid()
plt.savefig("../output_data/latitude_v_wind_speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#dataframes for north & south
northern_hemisphere = city_df.loc[city_df["Lat"] >= 0]
southern_hemisphere = city_df.loc[city_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Linear Regression Plots for North

x_values = pd.to_numeric(northern_hemisphere["Lat"]).astype(float)
y_values = pd.to_numeric(northern_hemisphere["Max Temp"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " +str(round(intercept,2))

# plot for northern hemisphere - max temp v/ latitude linear regression

fig1,ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r--")
plt.annotate(line_eq,(15,10),fontsize=16,color="purple")
plt.xlabel("Latitude")
plt.ylabel("Max Temp(F)")
plt.title(f"Northern Hemisphere - Max Temp v/ Latitude Linear Regression")

plt.grid()

#calculations of p/r values
print(f"The P-Value is: {pvalue}")
print(f"The R-Value is: {rvalue}")
#save plot as png
plt.savefig("../output_data/north_hemisphere_maxtemp_latitude_LR", bbox_inches = "tight")
plt.show()
# Out:
# The P-Value is: 4.16675242763289e-97
# The R-Value is: -0.8213233072788

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Linear Regression Plots for South

x_values = pd.to_numeric(southern_hemisphere["Lat"]).astype(float)
y_values = pd.to_numeric(southern_hemisphere["Max Temp"]).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " +str(round(intercept,2))

# plot for southern hemisphere - max temp v/ latitude linear regression
fig1,ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r--")
plt.annotate(line_eq,(-35,67),fontsize=16,color="purple")
plt.xlabel("Latitude")
plt.ylabel("Max Temp(F)")
plt.title("Southern - Max Temp v/ Latitude Linear Regression")
plt.grid()
#calculations of p/r values
print(f"The P-Value is: {pvalue}")
print(f"The R-Value is: {rvalue}")
#save plot as png
plt.savefig("../output_data/south_hemisphere_maxtemp_latitude_LR" ,bbox_inches = "tight")
plt.show()
# Out:
# The P-Value is: 2.5453617922138748e-09
# The R-Value is: 0.44796550949438657

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - %Humidity v/ %Humidity Latitude Linear Regression
x_values = pd.to_numeric(northern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemisphere['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot data
fig1,ax1 = plt.subplots(figsize=(10,8))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(60,65),fontsize=15,color="blue")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Northern Hemisphere - Humidity % v/ Latitude Linear Regression")

plt.grid()

#calculations of p/r values
print(f"The P-Value is: {pvalue}")
print(f"The R-Value is: {rvalue}")
#save plot as png
plt.savefig("../output_data/north_hemisphere_humidity_latitude_LR", bbox_inches = "tight")
plt.show()
# Out:
# The P-Value is: 3.658329365701117e-14
# The R-Value is: 0.36999779163002505

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - %Humidity v/ Latitude Linear Regression
x_values = pd.to_numeric(southern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemisphere['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot data
fig1,ax1 = plt.subplots(figsize=(15,10))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25, 30),fontsize=15,color="blue")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Southern Hemisphere - Humidity % v/ Latitude Linear Regression")

plt.grid()

#calculations of p/r values
print(f"The P-Value is: {pvalue}")
print(f"The R-Value is: {rvalue}")
#save plot as png
plt.savefig("../output_data/south_hemisphere_humidity_latitude_LR", bbox_inches = "tight")
plt.show()
# Out:
# The P-Value is: 3.0685397947228325e-14
# The R-Value is: 0.5523277849288886

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Cloudiness v/ Latitude Linear Regression
x_values = pd.to_numeric(northern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemisphere['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot data
fig1,ax1 = plt.subplots(figsize=(15,10))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(60, 10),fontsize=15,color="green")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Southern Hemisphere - Cloudiness v/ Latitude Linear Regression")

plt.grid()

#calculations of p/r values
print(f"The P-Value is: {pvalue}")
print(f"The R-Value is: {rvalue}")
#save plot as png
plt.savefig("../output_data/north_hemisphere_cloudiness_latitude_LR", bbox_inches = "tight")
plt.show()
# Out:
# The P-Value is: 1.941901667358267e-15
# The R-Value is: 0.38679291880361993

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Cloudiness v/ Latitude Linear Regression
x_values = pd.to_numeric(southern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemisphere['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot data
fig1,ax1 = plt.subplots(figsize=(15,10))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20, 5),fontsize=15,color="green")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Southern Hemisphere - Cloudiness % v/ Latitude Linear Regression")

plt.grid()

#calculations of p/r values
print(f"The P-Value is: {pvalue}")
print(f"The R-Value is: {rvalue}")
#save plot as png
plt.savefig("../output_data/south_hemisphere_cloudiness_latitude_LR", bbox_inches = "tight")
plt.show()
# Out:
# The P-Value is: 1.3557691707801928e-09
# The R-Value is: 0.4547952396514572

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Wind Speed v/ Latitude Linear Regression
x_values = pd.to_numeric(northern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemisphere['Wind']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot data
fig1,ax1 = plt.subplots(figsize=(15,10))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10, 0),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Northern Hemisphere - Wind Speed(mph) % v/ Latitude Linear Regression")

plt.grid()

#calculations of p/r values
print(f"The P-Value is: {pvalue}")
print(f"The R-Value is: {rvalue}")
#save plot as png
plt.savefig("../output_data/north_hemisphere_cloudiness_latitude_LR", bbox_inches = "tight")
plt.show()
# Out:
# The P-Value is: 0.004869874223894493
# The R-Value is: 0.14193774623800132

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Wind Speed v/ Latitude Linear Regression
x_values = pd.to_numeric(southern_hemisphere['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemisphere['Wind']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot data
fig1,ax1 = plt.subplots(figsize=(15,10))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-10, 2),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Southern Hemisphere - Wind Speed(mph) % v/ Latitude Linear Regression")

plt.grid()

#calculations of p/r values
print(f"The P-Value is: {pvalue}")
print(f"The R-Value is: {rvalue}")
#save plot as png
plt.savefig("../output_data/south_hemisphere_cloudiness_latitude_LR", bbox_inches = "tight")
plt.show()
# Out:
# The P-Value is: 0.0026943788680483913
# The R-Value is: -0.2349917335069521
